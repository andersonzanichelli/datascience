# %% [markdown]
# # Lattice

# %%
install.packages('lattice')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(lattice)

# %%
xyplot(data = iris, groups = Species, Sepal.Length ~ Petal.Length)
# Out:
# plot without title

# %%
barchart(Class ~ Freq | Sex + Age, data = as.data.frame(Titanic),
        groups ~ Survived, stack = T, layout = c(4, 1),
        auto.key = list(title = 'Titanic Dataset', columns = 2))
# Out:
# Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”
# plot without title

# %%
barchart(Class ~ Freq | Sex + Age, data = as.data.frame(Titanic),
        groups ~ Survived, stack = T, layout = c(4, 1),
        auto.key = list(title = 'Titanic Dataset', columns = 2),
        scales = list(x = 'free'))
# Out:
# Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”Warning message in formals(fun):
# “argument is not a function”
# plot without title

# %%
xyplot(Sepal.Length ~ Sepal.Width | Petal.Length, data = iris)
# Out:
# plot without title

# %%
histogram(~Sepal.Length | Species, xlab = "", data = iris,
         layout = c(3,1), type = 'density',
         main = 'Lattice Histogram', sub = 'Iris dataset')
# Out:
# plot without title
