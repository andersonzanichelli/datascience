# %% [markdown]
# # Reading XLS Files

# %%
install.packages('rjava')
install.packages('xlsx')
install.packages('XLConnect')
install.packages('readxl')
install.packages('gdata')
# Out:
# Warning message:
# “package ‘rjava’ is not available (for R version 3.5.1)”Warning message:
# “Perhaps you meant ‘rJava’ ?”also installing the dependency ‘xlsxjars’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependency ‘XLConnectJars’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependency ‘progress’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependency ‘gtools’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(rJava)

# %%
library(readxl)

# %%
excel_sheets('../../../../datasets/UrbanPop.xlsx')
# Out:
# [1] "Period1" "Period2" "Period3"

# %%
df = read_excel('../../../../datasets/UrbanPop.xlsx')

# %%
head(df)
# Out:
#   country               1960    1961      1962      1963       1964
# 1 Abkhazia                   NA        NA        NA         NA         NA
# 2 Afghanistan            769308  814923.0  858521.7  903913.86  951225.94
# 3 Akrotiri and Dhekelia      NA        NA        NA         NA         NA
# 4 Albania                494443  511802.8  529438.9  547376.75  565571.75
# 5 Algeria               3293999 3515147.5 3739963.0 3973289.13 4220987.01
# 6 American Samoa             NA   13660.3   14165.8   14758.93   15396.42
#   1965       1966
# 1         NA         NA
# 2 1000582.35 1058743.47
# 3         NA         NA
# 4  583982.89  602512.17
# 5 4488175.64 4649105.24
# 6   16044.82   16693.11

# %%
df2 = read_excel('../../../../datasets/UrbanPop.xlsx', sheet = 2)
head(df2)
# Out:
#   country               1967       1968       1969       1970       1971
# 1 Abkhazia                      NA         NA         NA         NA         NA
# 2 Afghanistan           1119067.20 1182159.06 1248900.79 1319848.78 1409001.09
# 3 Akrotiri and Dhekelia         NA         NA         NA         NA         NA
# 4 Albania                621179.85  639964.46  658853.12  677839.12  698932.25
# 5 Algeria               4826104.22 5017298.60 5219331.87 5429743.08 5619041.53
# 6 American Samoa          17348.66   17995.51   18618.68   19206.39   19752.02
#   1972       1973       1974
# 1         NA         NA         NA
# 2 1502401.79 1598835.45 1696444.83
# 3         NA         NA         NA
# 4  720206.57  741681.04  763385.45
# 5 5815734.49 6020647.35 6235114.38
# 6   20262.67   20741.97   21194.38

# %%
df3 = read_excel('../../../../datasets/UrbanPop.xlsx', sheet = 3)
head(df3)
# Out:
#   country               1975       1976       1977       1978      1979
# 1 Abkhazia                      NA         NA         NA        NA         NA
# 2 Afghanistan           1793266.13 1905032.58 2021307.69 2142247.7 2268014.57
# 3 Akrotiri and Dhekelia         NA         NA         NA        NA         NA
# 4 Albania                785350.02  807989.83  830959.17  854262.4  877898.15
# 5 Algeria               6460138.04 6774099.23 7102902.29 7447728.4 7810072.95
# 6 American Samoa          21631.68   22046.65   22452.41   22899.5   23457.29
#   1980       1981       1982      1983       ⋯ 2002        2003
# 1         NA         NA        NA         NA ⋯          NA          NA
# 2 2398775.03 2493264.95 2590846.4 2691611.83 ⋯  5795939.88  6036099.72
# 3         NA         NA        NA         NA ⋯          NA          NA
# 4  901884.31  927223.82  952447.4  978476.39 ⋯  1352278.42  1391143.43
# 5 8190772.27 8637724.15 9105820.4 9591900.05 ⋯ 19854835.29 20529355.66
# ...

# %%
df4 = read_excel('../../../../datasets/UrbanPop.xlsx', sheet = 4)
# Out:
# Error: Can't retrieve sheet in position 4, only 3 sheet(s) found.
# Traceback:
#
# 1. read_excel("../../../../datasets/UrbanPop.xlsx", sheet = 4)
# 2. read_excel_(path = path, sheet = sheet, range = range, col_names = col_names,
#  .     col_types = col_types, na = na, trim_ws = trim_ws, skip = skip,
#  .     n_max = n_max, guess_max = guess_max, progress = progress,
#  .     .name_repair = .name_repair, format = format)
# 3. set_readxl_names(read_fun(path = enc2native(normalizePath(path)),
#  .     sheet_i = sheet, limits = limits, shim = shim, col_names = col_names,
#  .     col_types = col_types, na = na, trim_ws = trim_ws, guess_max = guess_max,
#  .     progress = progress), .name_repair = .name_repair)
# 4. tibble::as_tibble(l, .name_repair = .name_repair)
# 5. read_fun(path = enc2native(normalizePath(path)), sheet_i = sheet,
#  .     limits = limits, shim = shim, col_names = col_names, col_types = col_types,
# ...

# %%
dfAll = lapply(excel_sheets('../../../../datasets/UrbanPop.xlsx'), read_excel, path = '../../../../datasets/UrbanPop.xlsx')
dfAll
# Out:
# [[1]]
# # A tibble: 273 x 8
#    country            `1960`   `1961`   `1962`   `1963`   `1964`  `1965`  `1966`
#    <chr>               <dbl>    <dbl>    <dbl>    <dbl>    <dbl>   <dbl>   <dbl>
#  1 Abkhazia               NA      NA       NA       NA       NA  NA      NA
#  2 Afghanistan        769308  814923.  858522.  903914.  951226.  1.00e6  1.06e6
#  3 Akrotiri and Dhe…      NA      NA       NA       NA       NA  NA      NA
#  4 Albania            494443  511803.  529439.  547377.  565572.  5.84e5  6.03e5
#  5 Algeria           3293999 3515148. 3739963. 3973289. 4220987.  4.49e6  4.65e6
#  6 American Samoa         NA   13660.   14166.   14759.   15396.  1.60e4  1.67e4
#  7 Andorra                NA    8724.    9700.   10748.   11866.  1.31e4  1.42e4
#  8 Angola             521205  548265.  579695.  612087.  645262.  6.79e5  7.18e5
#  9 Anguilla               NA      NA       NA       NA       NA  NA      NA
# ...

# %%
detach(package:readxl)
library(XLConnect)
# Out:
# Loading required package: XLConnectJars
# XLConnect 0.2-15 by Mirai Solutions GmbH [aut],
#   Martin Studer [cre],
#   The Apache Software Foundation [ctb, cph] (Apache POI),
#   Graph Builder [ctb, cph] (Curvesapi Java library)
# http://www.mirai-solutions.com
# https://github.com/miraisolutions/xlconnect

# %%
wb = loadWorkbook('../../../../datasets/UrbanPop.xlsx')
df1 = readWorksheet(wb, sheet = 1, header = T)
head(df1)
# Out:
#   country               X1960   X1961     X1962     X1963      X1964
# 1 Abkhazia                   NA        NA        NA         NA         NA
# 2 Afghanistan            769308  814923.0  858521.7  903913.86  951225.94
# 3 Akrotiri and Dhekelia      NA        NA        NA         NA         NA
# 4 Albania                494443  511802.8  529438.9  547376.75  565571.75
# 5 Algeria               3293999 3515147.5 3739963.0 3973289.13 4220987.01
# 6 American Samoa             NA   13660.3   14165.8   14758.93   15396.42
#   X1965      X1966
# 1         NA         NA
# 2 1000582.35 1058743.47
# 3         NA         NA
# 4  583982.89  602512.17
# 5 4488175.64 4649105.24
# 6   16044.82   16693.11

# %%
class(df1)
# Out:
# [1] "data.frame"

# %%
detach(package:XLConnect)
library(xlsx)

# %%
df1 = read.xlsx('../../../../datasets/UrbanPop.xlsx', sheetIndex = 1)
head(df1)
# Out:
#   country               X1960   X1961     X1962     X1963      X1964
# 1 Abkhazia                   NA        NA        NA         NA         NA
# 2 Afghanistan            769308  814923.0  858521.7  903913.86  951225.94
# 3 Akrotiri and Dhekelia      NA        NA        NA         NA         NA
# 4 Albania                494443  511802.8  529438.9  547376.75  565571.75
# 5 Algeria               3293999 3515147.5 3739963.0 3973289.13 4220987.01
# 6 American Samoa             NA   13660.3   14165.8   14758.93   15396.42
#   X1965      X1966
# 1         NA         NA
# 2 1000582.35 1058743.47
# 3         NA         NA
# 4  583982.89  602512.17
# 5 4488175.64 4649105.24
# 6   16044.82   16693.11

# %%
detach(package:xlsx)
library(gdata)
# Out:
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
# gdata: read.xls support for 'XLSX' (Excel 2007+) files ENABLED.
#
# Attaching package: ‘gdata’
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
# The following object is masked from ‘package:base’:
#
#     startsWith

# %%
connection = xls2csv('../../../../datasets/planilha1.xlsx', sheet = 1, na.strings = 'EMPTY')
df = read.csv(connection)
head(df)
# Out:
#   X Akrotiri.and.Dhekelia Col2    X.1
# 1 1 Albania               494443  NA
# 2 2 Algeria               3293999 NA
# 3 3 American Samoa        #N/A    NA
# 4 4 Andorra               #N/A    NA
# 5 5 Angola                521205  NA
# 6 6 Anguilla              #N/A    NA
