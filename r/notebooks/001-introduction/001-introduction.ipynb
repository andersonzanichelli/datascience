# %% [markdown]
# # Introduction to R language

# %%
sessionInfo()
# Out:
# R version 3.5.1 (2018-07-02)
# Platform: x86_64-conda_cos6-linux-gnu (64-bit)
# Running under: Debian GNU/Linux 9 (stretch)
#
# Matrix products: default
# BLAS/LAPACK: /home/anderzanic/App/anaconda3/lib/R/lib/libRblas.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] compiler_3.5.1  magrittr_1.5    IRdisplay_0.5.0 pbdZMQ_0.3-3
#  [5] tools_3.5.1     htmltools_0.3.6 base64enc_0.1-3 crayon_1.3.4
#  [9] Rcpp_0.12.18    uuid_0.1-2      stringi_1.2.4   IRkernel_0.8.12
# [13] jsonlite_1.5    stringr_1.3.1   digest_0.6.15   repr_0.15.0
# [17] evaluate_0.11

# %%
plot(1:25)
# Out:
# plot without title

# %% [markdown]
# ## Installing packages

# %%
install.packages('randomForest')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
head(installed.packages())
# Out:
#            Package    LibPath                                      Version
# abind      abind      /home/anderzanic/App/anaconda3/lib/R/library 1.4-5
# assertthat assertthat /home/anderzanic/App/anaconda3/lib/R/library 0.2.0
# backports  backports  /home/anderzanic/App/anaconda3/lib/R/library 1.1.2
# base       base       /home/anderzanic/App/anaconda3/lib/R/library 3.5.1
# base64enc  base64enc  /home/anderzanic/App/anaconda3/lib/R/library 0.1-3
# BH         BH         /home/anderzanic/App/anaconda3/lib/R/library 1.66.0-1
#            Priority Depends      Imports        LinkingTo Suggests Enhances
# abind      NA       R (>= 1.5.0) methods, utils NA        NA       NA
# assertthat NA       NA           tools          NA        testthat NA
# backports  NA       R (>= 3.0.0) utils          NA        NA       NA
# base       base     NA           NA             NA        methods  NA
# base64enc  NA       R (>= 2.9.0) NA             NA        NA       png
# BH         NA       NA           NA             NA        NA       NA
#            License         License_is_FOSS License_restricts_use OS_type MD5sum
# abind      LGPL (>= 2)     NA              NA                    NA      NA
# assertthat GPL-3           NA              NA                    NA      NA
# backports  GPL-2           NA              NA                    NA      NA
# base       Part of R 3.5.1 NA              NA                    NA      NA
# base64enc  GPL-2 | GPL-3   NA              NA                    NA      NA
# BH         BSL-1.0         NA              NA                    NA      NA
#            NeedsCompilation Built
# abind      no               3.5.1
# assertthat no               3.5.1
# backports  yes              3.5.1
# base       NA               3.5.1
# base64enc  yes              3.5.1
# BH         no               3.5.1

# %%
install.packages('ggplot2')
install.packages('dplyr')
install.packages('devtools')
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependencies ‘cli’, ‘fansi’, ‘pillar’, ‘pkgconfig’, ‘Rcpp’, ‘rlang’, ‘tibble’, ‘tidyselect’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# also installing the dependencies ‘ini’, ‘desc’, ‘xopen’, ‘clisymbols’, ‘fs’, ‘gh’, ‘pkgbuild’, ‘pkgload’, ‘rcmdcheck’, ‘remotes’, ‘sessioninfo’, ‘usethis’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
#load library
library(ggplot2)

# %%
#unload library
detach(package:ggplot2)

# %%
#Documentation
help(mean)
# Out:
# mean                   package:base                    R Documentation
#
# n
#
# n:
#
#      Generic function for the (trimmed) arithmetic mean.
#
# e:
#
#      mean(x, ...)
#
#      ## Default S3 method:
#      mean(x, trim = 0, na.rm = FALSE, ...)
#
# s:
#
#        x: An R object.  Currently there are methods for numeric/logical
#           vectors and date, date-time and time interval objects.
#           Complex vectors are allowed for ‘trim = 0’, only.
#
#     trim: the fraction (0 to 0.5) of observations to be trimmed from
#           each end of ‘x’ before the mean is computed.  Values of trim
#           outside that range are taken as the nearest endpoint.
#
#    na.rm: a logical value indicating whether ‘NA’ values should be
#           stripped before the computation proceeds.
#
#      ...: further arguments passed to or from other methods.
#
# e:
#
#      If ‘trim’ is zero (the default), the arithmetic mean of the values
#      in ‘x’ is computed, as a numeric or complex vector of length one.
#      If ‘x’ is not logical (coerced to numeric), numeric (including
#      integer) or complex, ‘NA_real_’ is returned, with a warning.
#
#      If ‘trim’ is non-zero, a symmetrically trimmed mean is computed
#      with a fraction of ‘trim’ observations deleted from each end
#      before the mean is computed.
#
# s:
#
#      Becker, R. A., Chambers, J. M. and Wilks, A. R. (1988) _The New S
#      Language_.  Wadsworth & Brooks/Cole.
#
# o:
#
#      ‘weighted.mean’, ‘mean.POSIXct’, ‘colMeans’ for row and column
#      means.
#
# s:
#
#      x <- c(0:10, 50)
#      xm <- mean(x)
#      c(xm, mean(x, trim = 0.10))

# %%
?mean
# Out:
# mean                   package:base                    R Documentation
#
# n
#
# n:
#
#      Generic function for the (trimmed) arithmetic mean.
#
# e:
#
#      mean(x, ...)
#
#      ## Default S3 method:
#      mean(x, trim = 0, na.rm = FALSE, ...)
#
# s:
#
#        x: An R object.  Currently there are methods for numeric/logical
#           vectors and date, date-time and time interval objects.
#           Complex vectors are allowed for ‘trim = 0’, only.
#
#     trim: the fraction (0 to 0.5) of observations to be trimmed from
#           each end of ‘x’ before the mean is computed.  Values of trim
#           outside that range are taken as the nearest endpoint.
#
#    na.rm: a logical value indicating whether ‘NA’ values should be
#           stripped before the computation proceeds.
#
#      ...: further arguments passed to or from other methods.
#
# e:
#
#      If ‘trim’ is zero (the default), the arithmetic mean of the values
#      in ‘x’ is computed, as a numeric or complex vector of length one.
#      If ‘x’ is not logical (coerced to numeric), numeric (including
#      integer) or complex, ‘NA_real_’ is returned, with a warning.
#
#      If ‘trim’ is non-zero, a symmetrically trimmed mean is computed
#      with a fraction of ‘trim’ observations deleted from each end
#      before the mean is computed.
#
# s:
#
#      Becker, R. A., Chambers, J. M. and Wilks, A. R. (1988) _The New S
#      Language_.  Wadsworth & Brooks/Cole.
#
# o:
#
#      ‘weighted.mean’, ‘mean.POSIXct’, ‘colMeans’ for row and column
#      means.
#
# s:
#
#      x <- c(0:10, 50)
#      xm <- mean(x)
#      c(xm, mean(x, trim = 0.10))

# %%
#Searching for help with a term
help.search('randomForest')
# Out:
# R Information
#
# Help files with alias or concept or title matching ‘randomForest’ using
# fuzzy matching:
#
#
# caret::varImp           Calculation of variable importance for
#                         regression and classification models
#   Aliases: varImp.randomForest, varImp.RandomForest
# randomForest::grow      Add trees to an ensemble
#   Aliases: grow.randomForest
# randomForest::importance
#                         Extract variable importance measure
#   Aliases: importance.randomForest
# randomForest::margin    Margins of randomForest Classifier
#   Aliases: margin.randomForest
# randomForest::MDSplot   Multi-dimensional Scaling Plot of Proximity
#                         matrix from randomForest
# randomForest::outlier   Compute outlying measures
#   Aliases: outlier.randomForest
# randomForest::partialPlot
#                         Partial dependence plot
#   Aliases: partialPlot.randomForest
# randomForest::plot.randomForest
#                         Plot method for randomForest objects
#   Aliases: plot.randomForest
# randomForest::predict.randomForest
#                         predict method for random forest objects
#   Aliases: predict.randomForest
# randomForest::randomForest
#                         Classification and Regression with Random
#                         Forest
#   Aliases: randomForest, randomForest.formula, randomForest.default,
#     print.randomForest
# randomForest::rfcv      Random Forest Cross-Valdidation for feature
#                         selection
# randomForest::rfImpute
#                         Missing Value Imputations by randomForest
# randomForest::tuneRF    Tune randomForest for the optimal mtry
#                         parameter
# randomForest::varUsed   Variables used in a random forest
# sparklyr::ml_random_forest_classifier
#                         Spark ML - Random Forest
#   Aliases: ml_random_forest_classifier, ml_random_forest,
#     ml_random_forest_regressor
#
#
# Type '?PKG::FOO' to inspect entries 'PKG::FOO', or 'TYPE?PKG::FOO' for
# entries like 'PKG::FOO-TYPE'.

# %%
??randomForest
# Out:
# R Information
#
# Help files with alias or concept or title matching ‘randomForest’ using
# fuzzy matching:
#
#
# caret::varImp           Calculation of variable importance for
#                         regression and classification models
#   Aliases: varImp.randomForest, varImp.RandomForest
# randomForest::grow      Add trees to an ensemble
#   Aliases: grow.randomForest
# randomForest::importance
#                         Extract variable importance measure
#   Aliases: importance.randomForest
# randomForest::margin    Margins of randomForest Classifier
#   Aliases: margin.randomForest
# randomForest::MDSplot   Multi-dimensional Scaling Plot of Proximity
#                         matrix from randomForest
# randomForest::outlier   Compute outlying measures
#   Aliases: outlier.randomForest
# randomForest::partialPlot
#                         Partial dependence plot
#   Aliases: partialPlot.randomForest
# randomForest::plot.randomForest
#                         Plot method for randomForest objects
#   Aliases: plot.randomForest
# randomForest::predict.randomForest
#                         predict method for random forest objects
#   Aliases: predict.randomForest
# randomForest::randomForest
#                         Classification and Regression with Random
#                         Forest
#   Aliases: randomForest, randomForest.formula, randomForest.default,
#     print.randomForest
# randomForest::rfcv      Random Forest Cross-Valdidation for feature
#                         selection
# randomForest::rfImpute
#                         Missing Value Imputations by randomForest
# randomForest::tuneRF    Tune randomForest for the optimal mtry
#                         parameter
# randomForest::varUsed   Variables used in a random forest
# sparklyr::ml_random_forest_classifier
#                         Spark ML - Random Forest
#   Aliases: ml_random_forest_classifier, ml_random_forest,
#     ml_random_forest_regressor
#
#
# Type '?PKG::FOO' to inspect entries 'PKG::FOO', or 'TYPE?PKG::FOO' for
# entries like 'PKG::FOO-TYPE'.

# %%
??matplot
# Out:
# R Information
#
# Help files with alias or concept or title matching ‘matplot’ using
# fuzzy matching:
#
#
# graphics::matplot       Plot Columns of Matrices
#   Aliases: matplot
# hexbin::plotMAhex       MA-plot using hexagon bins
# labeling::matplotlib    Matplotlib's labeling algorithm
#   Aliases: matplotlib
# viridisLite::viridis    Matplotlib 'viridis' and 'cividis' color map
#
#
# Type '?PKG::FOO' to inspect entries 'PKG::FOO', or 'TYPE?PKG::FOO' for
# entries like 'PKG::FOO-TYPE'.

# %%
example(matplot)
# Out:
# matplt> require(grDevices)
#
# matplt> matplot((-4:5)^2, main = "Quadratic") # almost identical to plot(*)
#
# matplt> sines <- outer(1:20, 1:4, function(x, y) sin(x / 20 * pi * y))
#
# matplt> matplot(sines, pch = 1:4, type = "o", col = rainbow(ncol(sines)))
# Plot with title “Quadratic”
# matplt> matplot(sines, type = "b", pch = 21:23, col = 2:5, bg = 2:5,
# matplt+         main = "matplot(...., pch = 21:23, bg = 2:5)")
# plot without title
# matplt> x <- 0:50/50
#
# matplt> matplot(x, outer(x, 1:8, function(x, k) sin(k*pi * x)),
# matplt+         ylim = c(-2,2), type = "plobcsSh",
# matplt+         main= "matplot(,type = \"plobcsSh\" )")
# Plot with title “matplot(...., pch = 21:23, bg = 2:5)”
# matplt> ## pch & type =  vector of 1-chars :
# matplt> matplot(x, outer(x, 1:4, function(x, k) sin(k*pi * x)),
# matplt+         pch = letters[1:4], type = c("b","p","o"))
# Plot with title “matplot(,type = "plobcsSh" )”
# matplt> lends <- c("round","butt","square")
#
# matplt> matplot(matrix(1:12, 4), type="c", lty=1, lwd=10, lend=lends)
# plot without title
# matplt> text(cbind(2.5, 2*c(1,3,5)-.4), lends, col= 1:3, cex = 1.5)
#
# matplt> table(iris$Species) # is data.frame with 'Species' factor
#
#     setosa versicolor  virginica
#         50         50         50
#
# matplt> iS <- iris$Species == "setosa"
#
# matplt> iV <- iris$Species == "versicolor"
#
# matplt> op <- par(bg = "bisque")
#
# matplt> matplot(c(1, 8), c(0, 4.5), type =  "n", xlab = "Length", ylab = "Width",
# matplt+         main = "Petal and Sepal Dimensions in Iris Blossoms")
# plot without title
# matplt> matpoints(iris[iS,c(1,3)], iris[iS,c(2,4)], pch = "sS", col = c(2,4))
#
# matplt> matpoints(iris[iV,c(1,3)], iris[iV,c(2,4)], pch = "vV", col = c(2,4))
#
# matplt> legend(1, 4, c("    Setosa Petals", "    Setosa Sepals",
# matplt+                "Versicolor Petals", "Versicolor Sepals"),
# matplt+        pch = "sSvV", col = rep(c(2,4), 2))
#
# matplt> nam.var <- colnames(iris)[-5]
#
# matplt> nam.spec <- as.character(iris[1+50*0:2, "Species"])
#
# matplt> iris.S <- array(NA, dim = c(50,4,3),
# matplt+                 dimnames = list(NULL, nam.var, nam.spec))
#
# matplt> for(i in 1:3) iris.S[,,i] <- data.matrix(iris[1:50+50*(i-1), -5])
#
# matplt> matplot(iris.S[, "Petal.Length",], iris.S[, "Petal.Width",], pch = "SCV",
# matplt+         col = rainbow(3, start = 0.8, end = 0.1),
# matplt+         sub = paste(c("S", "C", "V"), dimnames(iris.S)[[3]],
# matplt+                     sep = "=", collapse= ",  "),
# matplt+         main = "Fisher's Iris Data")
# Plot with title “Petal and Sepal Dimensions in Iris Blossoms”
# matplt> par(op)
# Plot with title “Fisher's Iris Data”
